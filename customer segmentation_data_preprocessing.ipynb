# %%
import os
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
# Out:
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
# Walk through "data" folder, printing directories and files 
# to use their names for file paths

for root, dirs, files in os.walk("data"):
    print("Current Directory:", root)
    print()
    print("Subdirectories:", dirs)
    print()
    print("Files:", files)
# Out:
# Current Directory: data
#
# Subdirectories: ['.ipynb_checkpoints', 'Processed', 'Raw']
#
# Files: ['customer_behavior.ipynb']
# Current Directory: data\.ipynb_checkpoints
#
# Subdirectories: []
#
# Files: ['customer_behavior-checkpoint.ipynb']
# Current Directory: data\Processed
#
# Subdirectories: ['.ipynb_checkpoints', 'customer_segmentation']
#
# Files: []
# Current Directory: data\Processed\.ipynb_checkpoints
#
# Subdirectories: []
#
# Files: []
# Current Directory: data\Processed\customer_segmentation
#
# Subdirectories: []
#
# Files: ['customer_segmentation.csv']
# Current Directory: data\Raw
#
# Subdirectories: []
#
# Files: ['E-commerce Customer Behavior - Sheet1.csv']

# %%
main_dir = 'data/raw/'
file_name = 'E-commerce Customer Behavior - Sheet1.csv'
file_path = os.path.join(main_dir, file_name)

# %%
df = pd.read_csv(file_path, index_col='Customer ID')

# %%
df.head()
# Out:
#              Gender  Age           City Membership Type  Total Spend  \
# Customer ID
# 101          Female   29       New York            Gold      1120.20
# 102            Male   34    Los Angeles          Silver       780.50
# 103          Female   43        Chicago          Bronze       510.75
# 104            Male   30  San Francisco            Gold      1480.30
# 105            Male   27          Miami          Silver       720.40
#
#              Items Purchased  Average Rating  Discount Applied  \
# Customer ID
# 101                       14             4.6              True
# 102                       11             4.1             False
# 103                        9             3.4              True
# 104                       19             4.7             False
# 105                       13             4.0              True
#
#              Days Since Last Purchase Satisfaction Level
# Customer ID
# 101                                25          Satisfied
# 102                                18            Neutral
# 103                                42        Unsatisfied
# 104                                12          Satisfied
# 105                                55        Unsatisfied

# %%
# df.info()

# %% [markdown]
# # process categorical data

# %%
categorical_columns = ['Discount Applied', 'Gender_Female', 'Gender_Male', 'City_Chicago', 'City_Houston', 
    'City_Los Angeles', 'City_Miami', 'City_New York', 'City_San Francisco', 
    'Membership Type_Bronze', 'Membership Type_Gold', 'Membership Type_Silver']

# %%
# Label Encoding (for ordinal data like Satisfaction Level)
label_encoder = LabelEncoder()
df['Satisfaction Level'] = label_encoder.fit_transform(df['Satisfaction Level'])

# One-Hot Encoding (for nominal data like Gender, City, Membership Type)
df = pd.get_dummies(df, columns=['Gender', 'City', 'Membership Type'])

# Convert the one-hot encoded columns to integers
df[categorical_columns] = df[categorical_columns].astype(int)

# %%
df
# Out:
#              Age  Total Spend  Items Purchased  Average Rating  \
# Customer ID
# 101           29      1120.20               14             4.6
# 102           34       780.50               11             4.1
# 103           43       510.75                9             3.4
# 104           30      1480.30               19             4.7
# 105           27       720.40               13             4.0
# ...          ...          ...              ...             ...
# 446           32       660.30               10             3.8
# 447           36       470.50                8             3.0
# 448           30      1190.80               16             4.5
# 449           34       780.20               11             4.2
# 450           43       515.75               10             3.3
#
#              Discount Applied  Days Since Last Purchase  Satisfaction Level  \
# Customer ID
# 101                         1                        25                   1
# 102                         0                        18                   0
# 103                         1                        42                   2
# 104                         0                        12                   1
# 105                         1                        55                   2
# ...                       ...                       ...                 ...
# 446                         1                        42                   2
# 447                         0                        27                   0
# 448                         1                        28                   1
# 449                         0                        21                   0
# 450                         1                        49                   2
#
#              Gender_Female  Gender_Male  City_Chicago  City_Houston  \
# Customer ID
# 101                      1            0             0             0
# 102                      0            1             0             0
# 103                      1            0             1             0
# 104                      0            1             0             0
# 105                      0            1             0             0
# ...                    ...          ...           ...           ...
# 446                      0            1             0             0
# 447                      1            0             0             1
# 448                      1            0             0             0
# 449                      0            1             0             0
# 450                      1            0             1             0
#
#              City_Los Angeles  City_Miami  City_New York  City_San Francisco  \
# Customer ID
# 101                         0           0              1                   0
# 102                         1           0              0                   0
# 103                         0           0              0                   0
# 104                         0           0              0                   1
# 105                         0           1              0                   0
# ...                       ...         ...            ...                 ...
# 446                         0           1              0                   0
# 447                         0           0              0                   0
# 448                         0           0              1                   0
# 449                         1           0              0                   0
# 450                         0           0              0                   0
#
#              Membership Type_Bronze  Membership Type_Gold  \
# Customer ID
# 101                               0                     1
# 102                               0                     0
# 103                               1                     0
# 104                               0                     1
# 105                               0                     0
# ...                             ...                   ...
# 446                               0                     0
# 447                               1                     0
# 448                               0                     1
# 449                               0                     0
# 450                               1                     0
#
#              Membership Type_Silver
# Customer ID
# 101                               0
# 102                               1
# 103                               0
# 104                               0
# 105                               1
# ...                             ...
# 446                               1
# 447                               0
# 448                               0
# 449                               1
# 450                               0
#
# [350 rows x 18 columns]

# %% [markdown]
# # process numerical

# %%
numerical_columns = ['Age', 'Total Spend', 'Items Purchased', 'Average Rating', 
                     'Days Since Last Purchase', 'Satisfaction Level']

# %%
# Apply Min-Max Normalization
scaler = MinMaxScaler()

# Normalize the numerical columns
final_df = pd.DataFrame(scaler.fit_transform(df), columns=df.columns, index=df.index)

# %%
final_df
# Out:
#                   Age  Total Spend  Items Purchased  Average Rating  \
# Customer ID
# 101          0.176471     0.639502         0.500000        0.842105
# 102          0.470588     0.333273         0.285714        0.578947
# 103          1.000000     0.090102         0.142857        0.210526
# 104          0.235294     0.964122         0.857143        0.894737
# 105          0.058824     0.279095         0.428571        0.526316
# ...               ...          ...              ...             ...
# 446          0.352941     0.224917         0.214286        0.421053
# 447          0.588235     0.053818         0.071429        0.000000
# 448          0.235294     0.703146         0.642857        0.789474
# 449          0.470588     0.333003         0.285714        0.631579
# 450          1.000000     0.094609         0.214286        0.157895
#
#              Discount Applied  Days Since Last Purchase  Satisfaction Level  \
# Customer ID
# 101                       1.0                  0.296296            0.333333
# 102                       0.0                  0.166667            0.000000
# 103                       1.0                  0.611111            0.666667
# 104                       0.0                  0.055556            0.333333
# 105                       1.0                  0.851852            0.666667
# ...                       ...                       ...                 ...
# 446                       1.0                  0.611111            0.666667
# 447                       0.0                  0.333333            0.000000
# 448                       1.0                  0.351852            0.333333
# 449                       0.0                  0.222222            0.000000
# 450                       1.0                  0.740741            0.666667
#
#              Gender_Female  Gender_Male  City_Chicago  City_Houston  \
# Customer ID
# 101                    1.0          0.0           0.0           0.0
# 102                    0.0          1.0           0.0           0.0
# 103                    1.0          0.0           1.0           0.0
# 104                    0.0          1.0           0.0           0.0
# 105                    0.0          1.0           0.0           0.0
# ...                    ...          ...           ...           ...
# 446                    0.0          1.0           0.0           0.0
# 447                    1.0          0.0           0.0           1.0
# 448                    1.0          0.0           0.0           0.0
# 449                    0.0          1.0           0.0           0.0
# 450                    1.0          0.0           1.0           0.0
#
#              City_Los Angeles  City_Miami  City_New York  City_San Francisco  \
# Customer ID
# 101                       0.0         0.0            1.0                 0.0
# 102                       1.0         0.0            0.0                 0.0
# 103                       0.0         0.0            0.0                 0.0
# 104                       0.0         0.0            0.0                 1.0
# 105                       0.0         1.0            0.0                 0.0
# ...                       ...         ...            ...                 ...
# 446                       0.0         1.0            0.0                 0.0
# 447                       0.0         0.0            0.0                 0.0
# 448                       0.0         0.0            1.0                 0.0
# 449                       1.0         0.0            0.0                 0.0
# 450                       0.0         0.0            0.0                 0.0
#
#              Membership Type_Bronze  Membership Type_Gold  \
# Customer ID
# 101                             0.0                   1.0
# 102                             0.0                   0.0
# 103                             1.0                   0.0
# 104                             0.0                   1.0
# 105                             0.0                   0.0
# ...                             ...                   ...
# 446                             0.0                   0.0
# 447                             1.0                   0.0
# 448                             0.0                   1.0
# 449                             0.0                   0.0
# 450                             1.0                   0.0
#
#              Membership Type_Silver
# Customer ID
# 101                             0.0
# 102                             1.0
# 103                             0.0
# 104                             0.0
# 105                             1.0
# ...                             ...
# 446                             1.0
# 447                             0.0
# 448                             0.0
# 449                             1.0
# 450                             0.0
#
# [350 rows x 18 columns]

# %% [markdown]
# # save the data

# %%
# Directory path where files will be saved
save_dir = 'data/processed/customer_segmentation'
cleaned_file_name = 'customer_segmentation.csv'
cleaned_file_path = os.path.join(save_dir, cleaned_file_name)

# %%
# Save the cleaned data
final_df.to_csv(cleaned_file_path, index=True)
print(f"File saved successfully at {cleaned_file_path}.")
# Out:
# File saved successfully at data/processed/customer_segmentation\customer_segmentation.csv.
